# %%
import os
import cv2
import numpy as np

# Path to the folder containing images
folder_path = "Folder/"

# Initialize lists to store images and labels
images = []
labels = []

# Iterate through each file in the folder
for filename in os.listdir(folder_path):
    
    # Read the image
    img = cv2.imread(os.path.join(folder_path, filename))
    if img is not None:
        
        # Label of The img
        label = filename[:-4] # <- Removing the format type
        
        # Append image and label to lists
        images.append(img)
        labels.append(label)

# Convert lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# %%
labels
# Out:
# array(['Screenshot 2024-01-30 015703 - Copy.png',
#        'Screenshot 2024-01-30 015703.png',
#        'Screenshot 2024-01-30 015715.png',
#        'Screenshot 2024-01-30 015726.png',
#        'Screenshot 2024-01-30 023607 - Copy.png',
#        'Screenshot 2024-01-30 023607.png',
#        'Screenshot 2024-01-30 023729.png',
#        'Screenshot 2024-01-30 024001.png',
#        'Screenshot 2024-01-30 024217.png'], dtype='<U39')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(pixel_matrix)

# %%
from PIL import Image

# Open an image file
image_path = "Notes/Screenshot 2024-01-30 015703 - Copy.png"
image = Image.open(image_path)

# Get the size of the image
width, height = image.size

# Initialize an empty matrix
pixel_matrix = []

# Access the pixel values and store them in the matrix
for y in range(height):
    row = []
    for x in range(width):
        pixel_value = image.getpixel((x, y))
        row.append(pixel_value)
    pixel_matrix.append(row)
